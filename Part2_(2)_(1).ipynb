# %%
# !pip install tensorflow_io
# Out:
# ...
#      |████████████████████████████████| 22.7MB 123kB/s
# ...
#      |████████████████████████████████| 2.3MB 45.3MB/s
# ...

# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/1118008/1877714/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210711%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210711T191855Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# The name is too long, 767 chars total.
# Trying to shorten...
# New name is archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20210711%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210711T191855Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=hos.
# --2021-07-12 16:43:38--  https://storage.googleapis.com/kaggle-data-sets/1118008/1877714/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210711%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210711T191855Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.188.128, 64.233.189.128, 108.177.97.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.188.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1035070855 (987M) [application/zip]
# ...

# %%
# !unzip DB.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Crema/1088_IWW_FEA_XX.wav
#   inflating: Crema/1088_IWW_HAP_XX.wav
#   inflating: Crema/1088_IWW_NEU_XX.wav
#   inflating: Crema/1088_IWW_SAD_XX.wav
#   inflating: Crema/1088_MTI_ANG_XX.wav
#   inflating: Crema/1088_MTI_DIS_XX.wav
#   inflating: Crema/1088_MTI_FEA_XX.wav
#   inflating: Crema/1088_MTI_HAP_XX.wav
#   inflating: Crema/1088_MTI_NEU_XX.wav
#   inflating: Crema/1088_MTI_SAD_XX.wav
#   inflating: Crema/1088_TAI_ANG_XX.wav
#   inflating: Crema/1088_TAI_DIS_XX.wav
#   inflating: Crema/1088_TAI_FEA_XX.wav
#   inflating: Crema/1088_TAI_HAP_XX.wav
#   inflating: Crema/1088_TAI_NEU_XX.wav
#   inflating: Crema/1088_TAI_SAD_XX.wav
#   inflating: Crema/1088_TIE_ANG_XX.wav
#   inflating: Crema/1088_TIE_DIS_XX.wav
#   inflating: Crema/1088_TIE_FEA_XX.wav
#   inflating: Crema/1088_TIE_HAP_XX.wav
#   inflating: Crema/1088_TIE_NEU_XX.wav
#   inflating: Crema/1088_TIE_SAD_XX.wav
#   inflating: Crema/1088_TSI_ANG_XX.wav
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave, sys
import os
import sys
from IPython.display import Audio
import librosa
import librosa.display
import tensorflow as tf
import tensorflow_io as tfio
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from sklearn import preprocessing
import numpy as np
import pandas as pd
import sklearn
import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from datetime import timedelta
from keras.layers import Activation as activation
from keras.callbacks import ModelCheckpoint

# %%
def visualize(path: str):
    
    # reading the audio file
    raw = wave.open(path)
    Audio(path)  
    # reads all the frames 
    # -1 indicates all or max frames
    signal = raw.readframes(-1)
    signal = np.frombuffer(signal, dtype ="int16")
      

    f_rate = raw.getframerate()
  

    time = np.linspace(
        0, # start
        len(signal) / f_rate,
        num = len(signal)
      
    )
    Audio(path)
   
  

    plt.figure(1)
      

    plt.title(path.split('_')[2])
      

    plt.xlabel("Time")
     
    # actual ploting
    plt.plot(time, signal)
      

    plt.show()

# %%
def createFileList(format='.wav'):
    fileList = []
    #print(/content/Crema)
    for root, dirs, files in os.walk('/content/Crema', topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# %%
fileList = createFileList()



Emotions=['HAP','DIS','FEA','NEU','SAD','ANG']
Emotions=np.array(Emotions)
#print(fileList[0].split('_')[0]+'_'+fileList[0].split('_')[1]+'_'+Emotions[0]+'_'+'XX.wav')
for feel in Emotions:
  path=fileList[1500].split('_')[0]+'_'+fileList[0].split('_')[1]+'_'+feel+'_'+'XX.wav'
  #path='1001'+'_'+'DFA'+'_'+feel+'_'+'XX.wav'

  visualize(path)

# %%
onehot_encoded_data=[]
for i in fileList:
  onehot_encoded_data.append([i.split('_')[2]])
emotion_df = pd.DataFrame( onehot_encoded_data , columns=['Emotions'] )

# dataframe for path of files.
path_df = pd.DataFrame(fileList, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)


onehot_encoded_data=np.array(onehot_encoded_data)
encoder = OneHotEncoder(sparse=False)
onehot_encoded_data = encoder.fit_transform(onehot_encoded_data)


Crema_df.head()
# Out:
#   Emotions                                Path
# 0      DIS  /content/Crema/1082_MTI_DIS_XX.wav
# 1      SAD  /content/Crema/1007_IWW_SAD_XX.wav
# 2      NEU  /content/Crema/1047_TSI_NEU_XX.wav
# 3      ANG  /content/Crema/1084_IEO_ANG_MD.wav
# 4      SAD  /content/Crema/1049_IOM_SAD_XX.wav

# %%
def shortTermEnergy(frame):
  return sum( [ abs(x)**2 for x in frame ] ) / len(frame)

# %%
def extract_features(data,sample_rate):
    #data, sample_rate = librosa.load(fileList)
    # ZCR
    result = np.array([])
    #zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    #result=np.hstack((result, zcr)) # stacking horizontally
#
    ## Chroma_stft
    #stft = np.abs(librosa.stft(data))
    #chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    #result = np.hstack((result, chroma_stft)) # stacking horizontally
#
    ## MFCC
    #mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    #result = np.hstack((result, mfcc)) # stacking horizontally
#
    ## Root Mean Square Value
    ##rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    ##result = np.hstack((result, rms)) # stacking horizontally
    #shortTerm = shortTermEnergy ((result,shortTermEnergy(data)))
    #result = np.hstack((result, shortTerm))

    spectral_rolloff = librosa.feature.spectral_rolloff(data, sr=sample_rate)[0]
    result = np.hstack((result, spectral_rolloff))

    spectral_centroids = librosa.feature.spectral_centroid(data, sr=sample_rate)[0]
    result = np.hstack((result, spectral_centroids)) 

    #mfccs = sklearn.preprocessing.scale(mfcc, axis=1)
    #result = np.hstack((mfccs, spectral_centroids))
    #spectral centroid


    
    #spectral bandwidth
    spec_bw = np.mean(librosa.feature.spectral_bandwidth(y=data, sr=sample_rate).T,axis = 0)
    result = np.hstack((result, spec_bw))

    #spectral flattness
    flatness = np.mean(librosa.feature.spectral_flatness(y=data).T,axis=0)
    result = np.hstack((result, flatness))

   


    return result

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
def get_features(path,istrain):
    # duration and offset are used to take care of the no audivvo in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path)#, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data,sample_rate)
    
    result = np.array(res1)
    if istrain == 1:
    # data with noise
    
      noise_data = noise(data)
      
      res2 = extract_features(noise_data,sample_rate)
      result = np.vstack((result, res2)) # stacking vertically
      
      # data with stretching and pitching
      #new_data = stretch(data)
      
      #data_stretch_pitch = pitch(new_data, sample_rate)
      #
      #res3 = extract_features(data_stretch_pitch,sample_rate)
      
      #result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
x_trainandvaildate, x_testpaths, y_trainandvaildate, y_testpaths = train_test_split(fileList, onehot_encoded_data ,test_size=0.3, random_state=0, shuffle=True)
x_trainpaths, x_validatepaths , y_trainpaths, y_validatepaths = train_test_split(x_trainandvaildate, y_trainandvaildate, test_size=0.1, random_state=0, shuffle=True)

# %%
x_trainpaths=np.array(x_trainpaths)
x_testpaths=np.array(x_testpaths)
x_validatepaths=np.array(x_validatepaths)


x_trainpaths.shape,x_testpaths.shape,x_validatepaths.shape
# Out:
# ((4688,), (2233,), (521,))

# %%
x_train, y_train = [], []

for path, emotion in zip(x_trainpaths , y_trainpaths):
    feature = get_features(path,1)
    for ele in feature:
        x_train.append(ele)
        y_train.append(emotion)
x_train=np.array(x_train)
y_train=np.array(y_train)
print(x_train.shape)

x_validate, y_validate = [], []

for path, emotion in zip(x_validatepaths , y_validatepaths):
    feature = get_features(path,0)
    for ele in feature:
        x_validate.append(ele)
        y_validate.append(emotion)
x_validate=np.array(x_validate)
y_validate=np.array(y_validate)
print(x_validate.shape)

x_test=[]
y_test=[]
for path, emotion in zip(x_testpaths , y_testpaths):
    feature = get_features(path,0)
    for ele in feature:
        x_test.append(ele)
        y_test.append(emotion)
x_test=np.array(x_test)
y_test=np.array(y_test)
print(x_test.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# (9376,)
# (116970,)
# (499022,)

# %%
data,sample_rate=librosa.load(x_trainpaths[0])

# %%
Features_Train = pd.DataFrame(x_train)
Features_Train['labels'] = y_train
Features_Train.to_csv('Features_Train.csv', index=False)
Features_Train.head()

Features_Test = pd.DataFrame(x_test)
Features_Test['labels'] = y_test
Features_Test.to_csv('Features_Test.csv', index=False)
Features_Test.head()


Features_Validate = pd.DataFrame(x_validate)
Features_Validate['labels'] = y_validate
Features_Validate.to_csv('Features_Validate.csv', index=False)
Features_Validate.head()
# print(Features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3575         try:
# -> 3576             loc = self._info_axis.get_loc(key)
#    3577         except KeyError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'labels'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-fb4f14aff246> in <module>()
#       1 Features_Train = pd.DataFrame(x_train)
# ----> 2 Features_Train['labels'] = y_train
# ...

# %%
len(X), len(Y)
# Out:
# (22326, 22326)

# %%
x_train = Features_Train.iloc[: ,:-1].values
y_train = Features_Train['labels'].values

x_test = Features_Test.iloc[: ,:-1].values
y_test = Features_Test['labels'].values

x_validate = Features_Validate.iloc[: ,:-1].values
y_validate = Features_Validate['labels'].values

# %%
x_train.shape , x_test.shape
# Out:
# ((9376, 34), (75922, 1))

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder 
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_validate=scaler.transform(x_validate)
x_train.shape, y_train.shape, x_test.shape, y_test.shape,x_validate,
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-40ab48405a9e> in <module>()
#       3 scaler = StandardScaler()
#       4 x_train = scaler.fit_transform(x_train)
# ----> 5 x_test = scaler.transform(x_test)
#       6 x_validate=scaler.transform(x_validate)
#       7 x_train.shape, y_train.shape, x_test.shape, y_test.shape
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     804         else:
#     805             if self.with_mean:
# --> 806                 X -= self.mean_
#     807             if self.with_std:
#     808                 X /= self.scale_
#
# ValueError: non-broadcastable output operand with shape (75922,1) doesn't match the broadcast shape (75922,34)

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_validate = np.expand_dims(x_validate, axis=2)
#y_train=np.expand_dims(y_train, axis=1)
x_train.shape, y_train.shape, x_test.shape, y_test.shape,x_validate.shape,y_validate.shape
# Out:
# ((9376, 34, 1, 1, 1),
#  (9376,),
#  (75922, 1, 1, 1, 1),
#  (75922,),
#  (17714, 1, 1, 1, 1),
#  (17714,))

# %%
y_train1=[]
for i in range(0,len(y_train)):
  y_train1.append(y_train[i])
y_train1=np.array(y_train1)  
print(y_train1.shape)  

y_validate1=[]
for i in range(0,len(y_validate)):
  y_validate1.append(y_validate[i])
y_validate1=np.array(y_validate1)  
print(y_validate1.shape)  



y_test1=[]
for i in range(0,len(y_test)):
  y_test1.append(y_test[i])
y_test1=np.array(y_test1)  
print(y_test1.shape)
# Out:
# (9376, 6)
# (75922, 6)
# (75922, 6)

# %%
import numpy as np
X = loadtxt('/content/domain_data_x.csv', delimiter=',')
#y_encoded = loadtxt('/content/drive/MyDrive/domain_y_decoded.txt', delimiter=',')

text_file = open("/content/final_y_decoded.txt", "r")
y = text_file.read().splitlines()
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a7bcc8dd87e2> in <module>()
#       1 import numpy as np
# ----> 2 X = loadtxt('/content/domain_data_x.csv', delimiter=',')
#       3 #y_encoded = loadtxt('/content/drive/MyDrive/domain_y_decoded.txt', delimiter=',')
#       4
#       5 text_file = open("/content/final_y_decoded.txt", "r")
#
# NameError: name 'loadtxt' is not defined

# %%
import numpy as np
x_train_np_array = None
y_train = None
x_test_np_array =None
y_test = None
x_validate_np_array = None
y_validte = None

with open('/content/features.npy', 'rb') as f:
    x_train_np_array = np.load(f)
    y_train = np.load(f)
    x_test_np_array = np.load(f)
    y_test = np.load(f)
    x_validate_np_array = np.load(f)
    y_validte = np.load(f)

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train_np_array.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
#model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=6, activation='softmax'))
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.01, amsgrad=True)
model.compile(optimizer = opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 35, 256)           1536
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 18, 256)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 18, 256)           327936
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 18, 128)           163968
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 9, 128)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 9, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 9, 64)             41024
# ...

# %%
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)

history=model.fit(x_train_np_array, y_train, batch_size=128, epochs=100, validation_data=(x_validate_np_array, y_validte), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 126/126 [==============================] - 48s 24ms/step - loss: 385.6158 - accuracy: 0.1732 - val_loss: 1.7914 - val_accuracy: 0.1577
# Epoch 2/100
# 126/126 [==============================] - 2s 16ms/step - loss: 1.7969 - accuracy: 0.1720 - val_loss: 1.7912 - val_accuracy: 0.1577
# Epoch 3/100
# 126/126 [==============================] - 2s 16ms/step - loss: 1.7992 - accuracy: 0.1732 - val_loss: 1.7911 - val_accuracy: 0.1577
# Epoch 4/100
# 126/126 [==============================] - 2s 16ms/step - loss: 1.7914 - accuracy: 0.1728 - val_loss: 1.7910 - val_accuracy: 0.1577
# Epoch 5/100
# 126/126 [==============================] - 2s 16ms/step - loss: 1.7930 - accuracy: 0.1739 - val_loss: 1.7909 - val_accuracy: 0.1577
# Epoch 6/100
# 126/126 [==============================] - 2s 16ms/step - loss: 1.7981 - accuracy: 0.1671 - val_loss: 1.7909 - val_accuracy: 0.1577
# Epoch 7/100
# ...

# %%
test_eval = model.evaluate(x_test_np_array, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 1.789749026298523
# Test accuracy: 0.16838334500789642

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(100)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-d37db153ceaa> in <module>()
#       8 plt.figure(figsize=(15, 15))
#       9 plt.subplot(2, 2, 1)
# ---> 10 plt.plot(epochs_range, acc, label='Training Accuracy')
#      11 plt.plot(epochs_range, val_acc, label='Validation Accuracy')
#      12 plt.legend(loc='lower right')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
lr = 0.001
generations = 20000
num_gens_to_wait = 250
batch_size = 512
drop_out_rate = 0.5
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K






# Set the target class number
target_class = 6
# Model 
model = Sequential()
model.add(Conv1D(256, 5, padding='same',input_shape=(x_train_np_array.shape[1],1))) #1
model.add(activation('relu'))
model.add(Conv1D(256, 5, padding='same')) #2
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 5, padding='same')) #3
model.add(activation('relu')) 
model.add(Conv1D(128, 5, padding='same')) #4
model.add(activation('relu'))
model.add(Conv1D(128, 5, padding='same')) #5
model.add(activation('relu'))
model.add(Conv1D(128, 3, padding='same')) #6
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=(8), padding='same'))
model.add(Conv1D(64, 3, padding='same')) #7
model.add(activation('relu'))
model.add(Conv1D(64, 3, padding='same')) #8
model.add(activation('relu'))
model.add(Flatten())
model.add(Dense(target_class)) #9
model.add(activation('softmax'))
opt = keras.optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False)
model.compile(optimizer = opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
#mcp_save = ModelCheckpoint(‘model/baseline_2class_np.h5’, save_best_only=True, monitor=’val_loss’, mode=’min’)
cnnhistory=model.fit(x_train_np_array, y_train, batch_size=64, epochs=300, validation_data=(x_validate_np_array, y_validte), callbacks=[ lr_reduce])
# Out:
# Epoch 1/300
# 232/232 [==============================] - 3s 9ms/step - loss: 1.4613 - accuracy: 0.3829 - val_loss: 1.5996 - val_accuracy: 0.3295
# Epoch 2/300
# 232/232 [==============================] - 2s 8ms/step - loss: 1.4631 - accuracy: 0.3867 - val_loss: 1.6040 - val_accuracy: 0.2912
# Epoch 3/300
# 232/232 [==============================] - 2s 7ms/step - loss: 1.4615 - accuracy: 0.3835 - val_loss: 1.4849 - val_accuracy: 0.3908
# Epoch 4/300
# 232/232 [==============================] - 2s 7ms/step - loss: 1.4621 - accuracy: 0.3843 - val_loss: 1.6043 - val_accuracy: 0.3257
# Epoch 5/300
# 232/232 [==============================] - 2s 7ms/step - loss: 1.4609 - accuracy: 0.3833 - val_loss: 1.6010 - val_accuracy: 0.3180
# Epoch 6/300
# 232/232 [==============================] - 2s 7ms/step - loss: 1.4563 - accuracy: 0.3917 - val_loss: 1.5932 - val_accuracy: 0.3027
# Epoch 7/300
# ...

# %%
test_eval = model.evaluate(x_test_np_array, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

acc = cnnhistory.history['accuracy']
val_acc = cnnhistory.history['val_accuracy']
loss = cnnhistory.history['loss']
val_loss = cnnhistory.history['val_loss']

epochs_range = range(300)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Test loss: 1.4584747552871704
# Test accuracy: 0.39498433470726013

# %%
from keras.regularizers import l2
model = Sequential()
model.add(Conv1D(64, kernel_size=(20), activation='relu', input_shape=(x_validate_np_array.shape[1],1)))
model.add(Conv1D(128, kernel_size=(20),padding='same',activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Dropout(0.4))
model.add(Conv1D(128, kernel_size=(20),activation='relu',padding='same'))
model.add(MaxPooling1D(pool_size=(8),padding='same'))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(6, activation='softmax'))
model.summary()
opt = keras.optimizers.Adam(lr=0.0001)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_24 (Conv1D)           (None, 18, 64)            1344
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 18, 128)           163968
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 2, 128)            0
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 2, 128)            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 2, 128)            327808
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# module_wrapper_8 (ModuleWrap (None, 1, 128)            0
# ...

# %%
model.compile(optimizer = opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
history=model.fit(x_train_np_array, y_train, batch_size=batch_size, epochs=150, validation_data=(x_validate_np_array, y_validte),verbose=1)
# Out:
# Epoch 1/150
# 29/29 [==============================] - 2s 27ms/step - loss: 2.4221 - accuracy: 0.1885 - val_loss: 2.4424 - val_accuracy: 0.2107
# Epoch 2/150
# 29/29 [==============================] - 0s 10ms/step - loss: 2.4157 - accuracy: 0.1956 - val_loss: 2.4368 - val_accuracy: 0.2337
# Epoch 3/150
# 29/29 [==============================] - 0s 9ms/step - loss: 2.4150 - accuracy: 0.1959 - val_loss: 2.4423 - val_accuracy: 0.1992
# Epoch 4/150
# 29/29 [==============================] - 0s 9ms/step - loss: 2.4200 - accuracy: 0.1838 - val_loss: 2.4371 - val_accuracy: 0.2146
# Epoch 5/150
# 29/29 [==============================] - 0s 9ms/step - loss: 2.4139 - accuracy: 0.1988 - val_loss: 2.4218 - val_accuracy: 0.2107
# Epoch 6/150
# 29/29 [==============================] - 0s 9ms/step - loss: 2.4176 - accuracy: 0.1885 - val_loss: 2.4156 - val_accuracy: 0.2375
# Epoch 7/150
# ...

# %%
# New model
model = Sequential()
model.add(Conv1D(256, 8, padding='same',input_shape=(x_train_np_array.shape[1],1)))  # X_train.shape[1] = No. of Columns
model.add(activation('relu'))
model.add(Conv1D(256, 8, padding='same'))
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.15))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.15))
model.add(MaxPooling1D(pool_size=(8),padding='same'))
model.add(Conv1D(64, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(64, 8, padding='same'))
model.add(activation('relu'))
model.add(Flatten())
model.add(Dense(6)) # Target class number
model.add(activation('softmax'))
# opt = keras.optimizers.SGD(lr=0.0001, momentum=0.0, decay=0.0, nesterov=False)
# opt = keras.optimizers.Adam(lr=0.0001)
opt = keras.optimizers.RMSprop(lr=0.01, decay=1e-6)

model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_94 (Conv1D)           (None, 37, 256)           2304
# _________________________________________________________________
# activation_77 (Activation)   (None, 37, 256)           0
# _________________________________________________________________
# conv1d_95 (Conv1D)           (None, 37, 256)           524544
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 37, 256)           1024
# _________________________________________________________________
# activation_78 (Activation)   (None, 37, 256)           0
# _________________________________________________________________
# module_wrapper_40 (ModuleWra (None, 37, 256)           0
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 4, 256)            0
# ...

# %%
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
history=model.fit(x_train_np_array, y_train, batch_size=16, epochs=300, validation_data=(x_validate_np_array, y_validte))
# Out:
# Epoch 1/300
# 928/928 [==============================] - 11s 9ms/step - loss: 1.7322 - accuracy: 0.2548 - val_loss: 1.5846 - val_accuracy: 0.3333
# Epoch 2/300
# 928/928 [==============================] - 8s 8ms/step - loss: 1.6206 - accuracy: 0.3083 - val_loss: 1.5698 - val_accuracy: 0.3333
# Epoch 3/300
# 928/928 [==============================] - 7s 8ms/step - loss: 1.5734 - accuracy: 0.3296 - val_loss: 1.4625 - val_accuracy: 0.4138
# Epoch 4/300
# 928/928 [==============================] - 7s 8ms/step - loss: 1.5658 - accuracy: 0.3385 - val_loss: 1.5321 - val_accuracy: 0.3410
# Epoch 5/300
# 928/928 [==============================] - 7s 8ms/step - loss: 1.5602 - accuracy: 0.3426 - val_loss: 1.4847 - val_accuracy: 0.3640
# Epoch 6/300
# 928/928 [==============================] - 7s 8ms/step - loss: 1.5359 - accuracy: 0.3569 - val_loss: 1.5101 - val_accuracy: 0.3755
# Epoch 7/300
# ...

# %%
test_eval = model.evaluate(x_test_np_array, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(300)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Test loss: 1.5353412628173828
# Test accuracy: 0.33766233921051025
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-324df6748c82> in <module>()
#      12 plt.figure(figsize=(15, 15))
#      13 plt.subplot(2, 2, 1)
# ---> 14 plt.plot(epochs_range, acc, label='Training Accuracy')
#      15 plt.plot(epochs_range, val_acc, label='Validation Accuracy')
#      16 plt.legend(loc='lower right')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
# ...

# %%
model = Sequential()
model.add(Conv1D(256, 8, padding='same',input_shape=(x_train_np_array.shape[1], 1)))
model.add(activation('relu'))
model.add(Conv1D(256, 8, padding='same'))
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(128, 8, padding='same'))
model.add(BatchNormalization())
model.add(activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=(8),padding='same'))
model.add(Conv1D(64, 8, padding='same'))
model.add(activation('relu'))
model.add(Conv1D(64, 8, padding='same'))
model.add(activation('relu'))
model.add(Flatten())
# 2-classes
model.add(Dense(6))
model.add(activation('softmax'))

# %%
opt = keras.optimizers.SGD(lr=0.0001, momentum=0.0, decay=0.0, nesterov=False)

# %%
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=10, min_lr=0.000001)
early = EarlyStopping(monitor="val_loss", mode="min", patience=5)

cnnhistory = model.fit(
                    x_train_np_array,
                    y_train,
                    batch_size=16,
                    epochs=300,
                    validation_data=(x_validate_np_array, y_validte),
                    callbacks=[ lr_reduce])

# %%
model=Sequential()





model.add(Conv1D(512, kernel_size=7, strides=1, padding='same', activation='relu', input_shape=(x_train_np_array.shape[1], 1),use_bias= True))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
# model.add(BatchNormalization())

model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu',use_bias= True))
model.add(MaxPooling1D(pool_size=3, strides = 2, padding = 'same'))
# model.add(BatchNormalization())

model.add(Conv1D(128, kernel_size=3, strides=1, padding='same', activation='relu',use_bias= True))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
# model.add(BatchNormalization())

model.add(Conv1D(64, kernel_size=3, strides=2, padding='same', activation='relu',use_bias= True))
model.add(Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu',use_bias= True))
model.add(Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu',use_bias= True))
model.add(Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu',use_bias= True))
# model.add(Conv1D(64, kernel_size=3, strides=2, padding='same', activation='relu',use_bias= True))

# model.add(BatchNormalization())
model.add(Flatten())
# model.add(Dense(units=512,activation='relu'))

# model.add(Dropout(0.2))

model.add(Dense(units=256, activation='relu',use_bias= True))
# model.add(Dropout(0.3))

model.add(Dense(units=6, activation='softmax'))
# opt = optimizers.Adam(lr=0.001)
opt = keras.optimizers.Adam(
  lr = 0.0003,decay=0.001
)

model.compile(optimizer=opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_70 (Conv1D)           (None, 35, 512)           4096
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 18, 512)           0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 18, 512)           1311232
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 9, 512)            0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 9, 128)            196736
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 5, 128)            0
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 3, 64)             24640
# ...

# %%
history=model.fit(x_train_np_array, y_train, batch_size=128, epochs=300, validation_data=(x_validate_np_array, y_validte))
# Out:
# Epoch 1/300
# 116/116 [==============================] - 49s 26ms/step - loss: 3.2632 - accuracy: 0.1903 - val_loss: 1.7090 - val_accuracy: 0.2452
# Epoch 2/300
# 116/116 [==============================] - 2s 14ms/step - loss: 1.7062 - accuracy: 0.2646 - val_loss: 1.6106 - val_accuracy: 0.3372
# Epoch 3/300
# 116/116 [==============================] - 2s 14ms/step - loss: 1.6156 - accuracy: 0.3133 - val_loss: 1.4927 - val_accuracy: 0.3946
# Epoch 4/300
# 116/116 [==============================] - 2s 14ms/step - loss: 1.5527 - accuracy: 0.3396 - val_loss: 1.4628 - val_accuracy: 0.3831
# Epoch 5/300
# 116/116 [==============================] - 2s 14ms/step - loss: 1.5230 - accuracy: 0.3588 - val_loss: 1.4802 - val_accuracy: 0.3870
# Epoch 6/300
# 116/116 [==============================] - 2s 14ms/step - loss: 1.5346 - accuracy: 0.3520 - val_loss: 1.4858 - val_accuracy: 0.4023
# Epoch 7/300
# ...

# %%
test_eval = model.evaluate(x_test_np_array, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(300)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Test loss: 1.4063557386398315
# Test accuracy: 0.43752798438072205

# %%
import pickle
with open('/content/encoder', "rb") as f: 
    
  encoder = pickle.load(f) 
  
pred_test = model.predict(x_test_np_array)
y_pred = encoder.inverse_transform(pred_test)
y_test1 = encoder.inverse_transform(y_test)

df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test1.flatten()

df.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator OneHotEncoder from version 0.24.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#   Predicted Labels Actual Labels
# 0              ANG           ANG
# 1              FEA           SAD
# 2              SAD           HAP
# 3              DIS           SAD
# 4              SAD           SAD
# 5              NEU           DIS
# 6              SAD           DIS
# 7              FEA           FEA
# 8              SAD           NEU
# 9              SAD           SAD

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

cm = confusion_matrix(y_test1, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
